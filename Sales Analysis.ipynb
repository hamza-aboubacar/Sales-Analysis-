# %%
import os 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
all_data=pd.read_csv('C:/Users/Halidou Boubacar/Desktop/data-sales-main/data-sales-main/all_data.csv')

# %%
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001
# 1                  NaN                                      NaN
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# ...                ...                                      ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
# [186850 rows x 6 columns]

# %%
all_data.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
all_data=all_data.dropna(how='all')

# %%
all_data.shape
# Out:
# (186305, 6)

# %%
def month(x):
    return x.split('/')[0]

# %%
all_data['Month']=all_data['Order Date'].apply(month)
# Out:
# C:\Users\Halidou Boubacar\AppData\Local\Temp\ipykernel_21340\2886953023.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month']=all_data['Order Date'].apply(month)

# %%
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address Month
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001    04
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215    04
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001    04
# ...                ...                                      ...   ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09
#
# [186305 rows x 7 columns]

# %%
all_data['Month'].unique()
# Out:
# array(['04', '05', 'Order Date', '08', '09', '12', '01', '02', '03', '07',
#        '06', '11', '10'], dtype=object)

# %%
all_data=all_data[all_data['Month']!='Order Date']

# %%
all_data['Month'].unique()
# Out:
# array(['04', '05', '08', '09', '12', '01', '02', '03', '07', '06', '11',
#        '10'], dtype=object)

# %%
all_data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Month               object
# dtype: object

# %%
all_data['Quantity Ordered']=all_data['Quantity Ordered'].astype(int)
# Out:
# C:\Users\Halidou Boubacar\AppData\Local\Temp\ipykernel_21340\1596566597.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Quantity Ordered']=all_data['Quantity Ordered'].astype(int)

# %%
all_data['Price Each']=all_data['Price Each'].astype(float)
# Out:
# C:\Users\Halidou Boubacar\AppData\Local\Temp\ipykernel_21340\470388495.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Price Each']=all_data['Price Each'].astype(float)

# %%
all_data.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int32
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Month                object
# dtype: object

# %%
all_data['Sales']=all_data['Quantity Ordered'] * all_data['Price Each']
# Out:
# C:\Users\Halidou Boubacar\AppData\Local\Temp\ipykernel_21340\2001310140.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Sales']=all_data['Quantity Ordered'] * all_data['Price Each']

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2        11.0
# 2        176559  Bose SoundSport Headphones                 1        99.0
# 3        176560                Google Phone                 1       600.0
# 4        176560            Wired Headphones                 1        11.0
# 5        176561            Wired Headphones                 1        11.0
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3         2.0
# 186846   259354                      iPhone                 1       700.0
# 186847   259355                      iPhone                 1       700.0
# 186848   259356      34in Ultrawide Monitor                 1       379.0
# 186849   259357        USB-C Charging Cable                 1        11.0
#
#             Order Date                         Purchase Address Month  Sales
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001    04   22.0
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215    04   99.0
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04  600.0
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04   11.0
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001    04   11.0
# ...                ...                                      ...   ...    ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09    6.0
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09  700.0
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09  700.0
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09  379.0
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09   11.0
#
# [185950 rows x 8 columns]

# %%
all_data.groupby('Month')['Sales'].sum()
# Out:
# Month
# 01    1813956.0
# 02    2191696.0
# 03    2794068.0
# 04    3374951.0
# 05    3138287.0
# 06    2566187.0
# 07    2635443.0
# 08    2234194.0
# 09    2087435.0
# 10    3719205.0
# 11    3184394.0
# 12    4591824.0
# Name: Sales, dtype: float64

# %%
months=range(1,13)

# %%
plt.bar(months,all_data.groupby('Month')['Sales'].sum())
plt.xlabel('Months number')
plt.ylabel('Sales en USD')
# Out:
# Text(0, 0.5, 'Sales en USD')

# %%
def city(x):
    return x.split(',')[1]

# %%
all_data['city']=all_data['Purchase Address'].apply(city)
# Out:
# C:\Users\Halidou Boubacar\AppData\Local\Temp\ipykernel_21340\3796087225.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['city']=all_data['Purchase Address'].apply(city)

# %%
all_data.groupby('city')['city'].count()
# Out:
# city
#  Atlanta          14881
#  Austin            9905
#  Boston           19934
#  Dallas           14820
#  Los Angeles      29605
#  New York City    24876
#  Portland         12465
#  San Francisco    44732
#  Seattle          14732
# Name: city, dtype: int64

# %%
plt.bar(all_data.groupby('city')['city'].count().index,all_data.groupby('city')['city'].count())
plt.xticks(rotation='vertical')
plt.xlabel('city')
plt.ylabel('orders')
# Out:
# Text(0, 0.5, 'orders')

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2        11.0
# 2        176559  Bose SoundSport Headphones                 1        99.0
# 3        176560                Google Phone                 1       600.0
# 4        176560            Wired Headphones                 1        11.0
# 5        176561            Wired Headphones                 1        11.0
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3         2.0
# 186846   259354                      iPhone                 1       700.0
# 186847   259355                      iPhone                 1       700.0
# 186848   259356      34in Ultrawide Monitor                 1       379.0
# 186849   259357        USB-C Charging Cable                 1        11.0
#
#             Order Date                         Purchase Address Month  Sales  \
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001    04   22.0
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215    04   99.0
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04  600.0
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04   11.0
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001    04   11.0
# ...                ...                                      ...   ...    ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09    6.0
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09  700.0
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09  700.0
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09  379.0
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09   11.0
#
#                   city
# 0               Dallas
# 2               Boston
# 3          Los Angeles
# 4          Los Angeles
# 5          Los Angeles
# ...                ...
# 186845     Los Angeles
# 186846   San Francisco
# 186847   San Francisco
# 186848   San Francisco
# 186849   San Francisco
#
# [185950 rows x 9 columns]

# %%
all_data['Hour']=pd.to_datetime(all_data['Order Date']).dt.hour
# Out:
# C:\Users\Halidou Boubacar\AppData\Local\Temp\ipykernel_21340\3083415790.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   all_data['Hour']=pd.to_datetime(all_data['Order Date']).dt.hour
# C:\Users\Halidou Boubacar\AppData\Local\Temp\ipykernel_21340\3083415790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Hour']=pd.to_datetime(all_data['Order Date']).dt.hour

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2        11.0
# 2        176559  Bose SoundSport Headphones                 1        99.0
# 3        176560                Google Phone                 1       600.0
# 4        176560            Wired Headphones                 1        11.0
# 5        176561            Wired Headphones                 1        11.0
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3         2.0
# 186846   259354                      iPhone                 1       700.0
# 186847   259355                      iPhone                 1       700.0
# 186848   259356      34in Ultrawide Monitor                 1       379.0
# 186849   259357        USB-C Charging Cable                 1        11.0
#
#             Order Date                         Purchase Address Month  Sales  \
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001    04   22.0
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215    04   99.0
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04  600.0
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04   11.0
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001    04   11.0
# ...                ...                                      ...   ...    ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09    6.0
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09  700.0
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09  700.0
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09  379.0
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09   11.0
#
#                   city  Hour
# 0               Dallas     8
# 2               Boston    22
# 3          Los Angeles    14
# 4          Los Angeles    14
# 5          Los Angeles     9
# ...                ...   ...
# 186845     Los Angeles    20
# 186846   San Francisco    16
# 186847   San Francisco     7
# 186848   San Francisco    17
# 186849   San Francisco     0
#
# [185950 rows x 10 columns]
